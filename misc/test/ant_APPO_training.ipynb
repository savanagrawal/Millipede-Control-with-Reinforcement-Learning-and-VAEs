# %%
import sys
from typing import Optional

import gymnasium as gym
import numpy as np
from sample_factory.cfg.arguments import parse_full_cfg, parse_sf_args
from sample_factory.envs.env_utils import register_env
from sample_factory.train import run_rl
from sf_examples.mujoco.mujoco_params import mujoco_override_defaults

# %%
class CustomAntEnv(gym.Wrapper):
    def __init__(self, env):
        super(CustomAntEnv, self).__init__(env)

    '''
    def step(self, action):
        xy_position_before = self.get_body_com("torso")[:2].copy()
        self.do_simulation(action, self.frame_skip)
        xy_position_after = self.get_body_com("torso")[:2].copy()

        xy_velocity = (xy_position_after - xy_position_before) / self.dt
        x_velocity, y_velocity = xy_velocity

        forward_reward = x_velocity
        healthy_reward = self.healthy_reward

        rewards = forward_reward + healthy_reward

        costs = ctrl_cost = self.control_cost(action)

        terminated = self.terminated
        observation = self._get_obs()
        info = {
            "reward_forward": forward_reward,
            "reward_ctrl": -ctrl_cost,
            "reward_survive": healthy_reward,
            "x_position": xy_position_after[0],
            "y_position": xy_position_after[1],
            "distance_from_origin": np.linalg.norm(xy_position_after, ord=2),
            "x_velocity": x_velocity,
            "y_velocity": y_velocity,
            "forward_reward": forward_reward,
        }
        if self._use_contact_forces:
            contact_cost = self.contact_cost
            costs += contact_cost
            info["reward_ctrl"] = -contact_cost

        reward = rewards - costs

        if self.render_mode == "human":
            self.render()
        return observation, reward, terminated, False, info
        
    '''

    def step(self, action):
        observation, reward, terminated, truncated, info = self.env.step(action)

        return observation, reward, terminated, truncated, info

# %%
def make_gym_env_func(full_env_name, cfg=None, env_config=None, render_mode: Optional[str] = None):
    base_env = gym.make(full_env_name, render_mode=render_mode)
    return CustomAntEnv(base_env)


def register_custom_components():
    register_env("Ant-v4", make_gym_env_func)


def parse_mujoco_cfg(argv=None, evaluation=False):
    parser, partial_cfg = parse_sf_args(argv=argv, evaluation=evaluation)
    # parser.set_defaults(
    #     batched_sampling=False,
    #     num_workers=8,
    #     num_envs_per_worker=8,
    #     worker_num_splits=2,
    #     train_for_env_steps=10000000,
    #     encoder_mlp_layers=[64, 64],
    #     env_frameskip=1,
    #     nonlinearity="tanh",
    #     batch_size=1024,
    #     kl_loss_coeff=0.1,
    #     use_rnn=False,
    #     adaptive_stddev=False,
    #     policy_initialization="torch_default",
    #     reward_scale=1,
    #     rollout=64,
    #     max_grad_norm=3.5,
    #     num_epochs=2,
    #     num_batches_per_epoch=4,
    #     ppo_clip_ratio=0.2,
    #     value_loss_coeff=1.3,
    #     exploration_loss_coeff=0.0,
    #     learning_rate=0.00295,
    #     lr_schedule="linear_decay",
    #     shuffle_minibatches=False,
    #     gamma=0.99,
    #     gae_lambda=0.95,
    #     with_vtrace=False,
    #     recurrence=1,
    #     normalize_input=True,
    #     normalize_returns=True,
    #     value_bootstrap=True,
    #     experiment_summaries_interval=3,
    #     save_every_sec=15,
    #     serial_mode=False,
    #     async_rl=False,
    # )
    mujoco_override_defaults(partial_cfg.env, parser)
    final_cfg = parse_full_cfg(parser, argv)
    return final_cfg

# %%
def main():
    """Script entry point."""
    register_custom_components()
    argv=["--env=Ant-v4", "--device=cpu", "--experiment=ant_APPO_tuned_params_v2"]
    cfg = parse_mujoco_cfg(argv, True)
    status = run_rl(cfg)
    return status


if __name__ == "__main__":
    main()
# Out:
# [2023-07-08 18:14:01,721][79971] Environment Ant-v4 already registered, overwriting...
# [2023-07-08 18:14:01,730][79971] Saved parameter configuration for experiment ant_APPO_tuned_params_v2 not found!
# [2023-07-08 18:14:01,730][79971] Starting experiment from scratch!
# [2023-07-08 18:14:01,737][79971] Experiment dir /Users/savan/Documents/UofG/MSc Project/Code/sample-factory/code/train_dir/ant_APPO_tuned_params_v2 already exists!
# [2023-07-08 18:14:01,738][79971] Resuming existing experiment from /Users/savan/Documents/UofG/MSc Project/Code/sample-factory/code/train_dir/ant_APPO_tuned_params_v2...
# [2023-07-08 18:14:01,738][79971] Weights and Biases integration disabled
# [2023-07-08 18:14:01,740][79971] Environment var CUDA_VISIBLE_DEVICES is
# Traceback (most recent call last):
#   File "<string>", line 1, in <module>
#   File "/Users/savan/.pyenv/versions/3.11.4/lib/python3.11/multiprocessing/spawn.py", line 120, in spawn_main
#     exitcode = _main(fd, parent_sentinel)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/savan/.pyenv/versions/3.11.4/lib/python3.11/multiprocessing/spawn.py", line 130, in _main
#     self = reduction.pickle.load(from_parent)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: Can't get attribute 'make_gym_env_func' on <module '__main__' (built-in)>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 11
#       7     return status
#      10 if __name__ == "__main__":
# ---> 11     main()
#
# Cell In[7], line 6, in main()
#       4 argv=["--env=Ant-v4", "--device=cpu", "--experiment=ant_APPO_tuned_params_v2"]
#       5 cfg = parse_mujoco_cfg(argv, True)
# ----> 6 status = run_rl(cfg)
#       7 return status
#
# File ~/.pyenv/versions/3.11.4/lib/python3.11/site-packages/sample_factory/train.py:37, in run_rl(cfg)
#      32 cfg, runner = make_runner(cfg)
#      34 # here we can register additional message or summary handlers
#      35 # see sf_examples/dmlab/train_dmlab.py for example
# ---> 37 status = runner.init()
#      38 if status == ExperimentStatus.SUCCESS:
#      39     status = runner.run()
#
# File ~/.pyenv/versions/3.11.4/lib/python3.11/site-packages/sample_factory/algo/runners/runner_parallel.py:21, in ParallelRunner.init(self)
#      20 def init(self) -> StatusCode:
# ---> 21     status = super().init()
#      22     if status != ExperimentStatus.SUCCESS:
#      23         return status
#
# File ~/.pyenv/versions/3.11.4/lib/python3.11/site-packages/sample_factory/algo/runners/runner.py:542, in Runner.init(self)
#     540 def init(self) -> StatusCode:
#     541     set_global_cuda_envvars(self.cfg)
# --> 542     self.env_info = obtain_env_info_in_a_separate_process(self.cfg)
#     544     for policy_id in range(self.cfg.num_policies):
#     545         self.reward_shaping[policy_id] = self.env_info.reward_shaping_scheme
#
# File ~/.pyenv/versions/3.11.4/lib/python3.11/site-packages/sample_factory/algo/utils/env_info.py:127, in obtain_env_info_in_a_separate_process(cfg)
#     124 p = ctx.Process(target=spawn_tmp_env_and_get_info, args=(sf_context, q, cfg))
#     125 p.start()
# --> 127 env_info = q.get()
#     128 p.join()
#     130 if cfg.use_env_info_cache:
#
# File ~/.pyenv/versions/3.11.4/lib/python3.11/multiprocessing/queues.py:103, in Queue.get(self, block, timeout)
#     101 if block and timeout is None:
#     102     with self._rlock:
# --> 103         res = self._recv_bytes()
#     104     self._sem.release()
#     105 else:
#
# File ~/.pyenv/versions/3.11.4/lib/python3.11/multiprocessing/connection.py:215, in _ConnectionBase.recv_bytes(self, maxlength)
#     213 if maxlength is not None and maxlength < 0:
#     214     raise ValueError("negative maxlength")
# --> 215 buf = self._recv_bytes(maxlength)
#     216 if buf is None:
#     217     self._bad_message_length()
#
# File ~/.pyenv/versions/3.11.4/lib/python3.11/multiprocessing/connection.py:413, in Connection._recv_bytes(self, maxsize)
#     412 def _recv_bytes(self, maxsize=None):
# --> 413     buf = self._recv(4)
#     414     size, = struct.unpack("!i", buf.getvalue())
#     415     if size == -1:
#
# File ~/.pyenv/versions/3.11.4/lib/python3.11/multiprocessing/connection.py:378, in Connection._recv(self, size, read)
#     376 remaining = size
#     377 while remaining > 0:
# --> 378     chunk = read(handle, remaining)
#     379     n = len(chunk)
#     380     if n == 0:
#
# KeyboardInterrupt:

# %%
from typing import Optional
import sys
import gymnasium as gym
import numpy as np
from sample_factory.cfg.arguments import parse_full_cfg, parse_sf_args
from sample_factory.envs.env_utils import register_env
from sample_factory.train import run_rl
from sf_examples.mujoco.mujoco_params import mujoco_override_defaults

class CustomAntEnv(gym.Wrapper):
    def __init__(self, env):
        super(CustomAntEnv, self).__init__(env)

    def step(self, action):
        observation, reward, terminated, truncated, info = self.env.step(action)

        return observation, reward, terminated, truncated, info
    
def make_gym_env_func(full_env_name, cfg=None, env_config=None, render_mode: Optional[str] = None):
    base_env = gym.make(full_env_name, render_mode=render_mode)
    return CustomAntEnv(base_env)


def register_custom_components():
    register_env("Ant-v4", make_gym_env_func)


def parse_mujoco_cfg(argv=None, evaluation=False):
    parser, partial_cfg = parse_sf_args(argv=argv, evaluation=evaluation)
    mujoco_override_defaults(partial_cfg.env, parser)
    final_cfg = parse_full_cfg(parser, argv)
    return final_cfg


def main():
    """Script entry point."""
    register_custom_components()
    argv=["--env=Ant-v4", "--device=cpu", "--experiment=ant_APPO_tuned_params"]
    cfg = parse_mujoco_cfg(argv, True)
    status = run_rl(cfg)
    return status

import dill
import multiprocessing

multiprocessing.set_start_method('spawn')
multiprocessing.current_process().daemon = False

sys.modules['__main__'] = __import__('__main__')
setattr(sys.modules['__main__'], 'make_gym_env_func', make_gym_env_func)


main()
# Out:
# [2023-07-08 18:52:10,370][83997] Loading existing experiment configuration from /Users/savan/Documents/UofG/MSc Project/Code/sample-factory/code/train_dir/ant_APPO_tuned_params/config.json
# [2023-07-08 18:52:10,381][83997] Experiment dir /Users/savan/Documents/UofG/MSc Project/Code/sample-factory/code/train_dir/ant_APPO_tuned_params already exists!
# [2023-07-08 18:52:10,381][83997] Resuming existing experiment from /Users/savan/Documents/UofG/MSc Project/Code/sample-factory/code/train_dir/ant_APPO_tuned_params...
# [2023-07-08 18:52:10,382][83997] Weights and Biases integration disabled
# [2023-07-08 18:52:10,389][83997] Environment var CUDA_VISIBLE_DEVICES is
# Traceback (most recent call last):
#   File "<string>", line 1, in <module>
#   File "/Users/savan/.pyenv/versions/3.11.4/lib/python3.11/multiprocessing/spawn.py", line 120, in spawn_main
#     exitcode = _main(fd, parent_sentinel)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/savan/.pyenv/versions/3.11.4/lib/python3.11/multiprocessing/spawn.py", line 130, in _main
#     self = reduction.pickle.load(from_parent)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: Can't get attribute 'make_gym_env_func' on <module '__main__' (built-in)>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 53
#      49 sys.modules['__main__'] = __import__('__main__')
#      50 setattr(sys.modules['__main__'], 'make_gym_env_func', make_gym_env_func)
# ---> 53 main()
#
# Cell In[1], line 40, in main()
#      38 argv=["--env=Ant-v4", "--device=cpu", "--experiment=ant_APPO_tuned_params"]
#      39 cfg = parse_mujoco_cfg(argv, True)
# ---> 40 status = run_rl(cfg)
#      41 return status
#
# File ~/.pyenv/versions/3.11.4/lib/python3.11/site-packages/sample_factory/train.py:37, in run_rl(cfg)
#      32 cfg, runner = make_runner(cfg)
#      34 # here we can register additional message or summary handlers
#      35 # see sf_examples/dmlab/train_dmlab.py for example
# ---> 37 status = runner.init()
#      38 if status == ExperimentStatus.SUCCESS:
#      39     status = runner.run()
#
# File ~/.pyenv/versions/3.11.4/lib/python3.11/site-packages/sample_factory/algo/runners/runner_parallel.py:21, in ParallelRunner.init(self)
#      20 def init(self) -> StatusCode:
# ---> 21     status = super().init()
#      22     if status != ExperimentStatus.SUCCESS:
#      23         return status
#
# File ~/.pyenv/versions/3.11.4/lib/python3.11/site-packages/sample_factory/algo/runners/runner.py:542, in Runner.init(self)
#     540 def init(self) -> StatusCode:
#     541     set_global_cuda_envvars(self.cfg)
# --> 542     self.env_info = obtain_env_info_in_a_separate_process(self.cfg)
#     544     for policy_id in range(self.cfg.num_policies):
#     545         self.reward_shaping[policy_id] = self.env_info.reward_shaping_scheme
#
# File ~/.pyenv/versions/3.11.4/lib/python3.11/site-packages/sample_factory/algo/utils/env_info.py:127, in obtain_env_info_in_a_separate_process(cfg)
#     124 p = ctx.Process(target=spawn_tmp_env_and_get_info, args=(sf_context, q, cfg))
#     125 p.start()
# --> 127 env_info = q.get()
#     128 p.join()
#     130 if cfg.use_env_info_cache:
#
# File ~/.pyenv/versions/3.11.4/lib/python3.11/multiprocessing/queues.py:103, in Queue.get(self, block, timeout)
#     101 if block and timeout is None:
#     102     with self._rlock:
# --> 103         res = self._recv_bytes()
#     104     self._sem.release()
#     105 else:
#
# File ~/.pyenv/versions/3.11.4/lib/python3.11/multiprocessing/connection.py:215, in _ConnectionBase.recv_bytes(self, maxlength)
#     213 if maxlength is not None and maxlength < 0:
#     214     raise ValueError("negative maxlength")
# --> 215 buf = self._recv_bytes(maxlength)
#     216 if buf is None:
#     217     self._bad_message_length()
#
# File ~/.pyenv/versions/3.11.4/lib/python3.11/multiprocessing/connection.py:413, in Connection._recv_bytes(self, maxsize)
#     412 def _recv_bytes(self, maxsize=None):
# --> 413     buf = self._recv(4)
#     414     size, = struct.unpack("!i", buf.getvalue())
#     415     if size == -1:
#
# File ~/.pyenv/versions/3.11.4/lib/python3.11/multiprocessing/connection.py:378, in Connection._recv(self, size, read)
#     376 remaining = size
#     377 while remaining > 0:
# --> 378     chunk = read(handle, remaining)
#     379     n = len(chunk)
#     380     if n == 0:
#
# KeyboardInterrupt:

# %%
from typing import Optional
import sys
import gymnasium as gym
import numpy as np
from sample_factory.cfg.arguments import parse_full_cfg, parse_sf_args
from sample_factory.envs.env_utils import register_env
from sample_factory.train import run_rl
from sf_examples.mujoco.mujoco_params import mujoco_override_defaults
from pathos.multiprocessing import ProcessingPool as Pool


class CustomAntEnv(gym.Wrapper):
    def __init__(self, env):
        super(CustomAntEnv, self).__init__(env)

    def step(self, action):
        observation, reward, terminated, truncated, info = self.env.step(action)

        return observation, reward, terminated, truncated, info
    
def make_gym_env_func(full_env_name, cfg=None, env_config=None, render_mode: Optional[str] = None):
    base_env = gym.make(full_env_name, render_mode=render_mode)
    return CustomAntEnv(base_env)


def register_custom_components():
    register_env("Ant-v4", make_gym_env_func)


def parse_mujoco_cfg(argv=None, evaluation=False):
    parser, partial_cfg = parse_sf_args(argv=argv, evaluation=evaluation)
    mujoco_override_defaults(partial_cfg.env, parser)
    final_cfg = parse_full_cfg(parser, argv)
    return final_cfg


def main():
    print("Starting main function")
    """Script entry point."""
    register_custom_components()
    argv=["--env=Ant-v4", "--device=cpu", "--experiment=ant_APPO_tuned_params"]
    cfg = parse_mujoco_cfg(argv, True)
    print("Running RL")
    status = run_rl(cfg)
    print("Finished RL")
    return status


if __name__ == '__main__':
    p = Pool(1)
    result = p.map(main, [])
    main()
# Out:
# [2023-07-08 18:56:49,427][84448] Loading existing experiment configuration from /Users/savan/Documents/UofG/MSc Project/Code/sample-factory/code/train_dir/ant_APPO_tuned_params/config.json
# [2023-07-08 18:56:49,446][84448] Experiment dir /Users/savan/Documents/UofG/MSc Project/Code/sample-factory/code/train_dir/ant_APPO_tuned_params already exists!
# [2023-07-08 18:56:49,446][84448] Resuming existing experiment from /Users/savan/Documents/UofG/MSc Project/Code/sample-factory/code/train_dir/ant_APPO_tuned_params...
# [2023-07-08 18:56:49,447][84448] Weights and Biases integration disabled
# [2023-07-08 18:56:49,454][84448] Environment var CUDA_VISIBLE_DEVICES is
# Starting main function
# Running RL
# Traceback (most recent call last):
#   File "<string>", line 1, in <module>
#   File "/Users/savan/.pyenv/versions/3.11.4/lib/python3.11/multiprocessing/spawn.py", line 120, in spawn_main
#     exitcode = _main(fd, parent_sentinel)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/savan/.pyenv/versions/3.11.4/lib/python3.11/multiprocessing/spawn.py", line 130, in _main
#     self = reduction.pickle.load(from_parent)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: Can't get attribute 'make_gym_env_func' on <module '__main__' (built-in)>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 52
#      50 p = Pool(1)
#      51 result = p.map(main, [])
# ---> 52 main()
#
# Cell In[3], line 44, in main()
#      42 cfg = parse_mujoco_cfg(argv, True)
#      43 print("Running RL")
# ---> 44 status = run_rl(cfg)
#      45 print("Finished RL")
#      46 return status
#
# File ~/.pyenv/versions/3.11.4/lib/python3.11/site-packages/sample_factory/train.py:37, in run_rl(cfg)
#      32 cfg, runner = make_runner(cfg)
#      34 # here we can register additional message or summary handlers
#      35 # see sf_examples/dmlab/train_dmlab.py for example
# ---> 37 status = runner.init()
#      38 if status == ExperimentStatus.SUCCESS:
#      39     status = runner.run()
#
# File ~/.pyenv/versions/3.11.4/lib/python3.11/site-packages/sample_factory/algo/runners/runner_parallel.py:21, in ParallelRunner.init(self)
#      20 def init(self) -> StatusCode:
# ---> 21     status = super().init()
#      22     if status != ExperimentStatus.SUCCESS:
#      23         return status
#
# File ~/.pyenv/versions/3.11.4/lib/python3.11/site-packages/sample_factory/algo/runners/runner.py:542, in Runner.init(self)
#     540 def init(self) -> StatusCode:
#     541     set_global_cuda_envvars(self.cfg)
# --> 542     self.env_info = obtain_env_info_in_a_separate_process(self.cfg)
#     544     for policy_id in range(self.cfg.num_policies):
#     545         self.reward_shaping[policy_id] = self.env_info.reward_shaping_scheme
#
# File ~/.pyenv/versions/3.11.4/lib/python3.11/site-packages/sample_factory/algo/utils/env_info.py:127, in obtain_env_info_in_a_separate_process(cfg)
#     124 p = ctx.Process(target=spawn_tmp_env_and_get_info, args=(sf_context, q, cfg))
#     125 p.start()
# --> 127 env_info = q.get()
#     128 p.join()
#     130 if cfg.use_env_info_cache:
#
# File ~/.pyenv/versions/3.11.4/lib/python3.11/multiprocessing/queues.py:103, in Queue.get(self, block, timeout)
#     101 if block and timeout is None:
#     102     with self._rlock:
# --> 103         res = self._recv_bytes()
#     104     self._sem.release()
#     105 else:
#
# File ~/.pyenv/versions/3.11.4/lib/python3.11/multiprocessing/connection.py:215, in _ConnectionBase.recv_bytes(self, maxlength)
#     213 if maxlength is not None and maxlength < 0:
#     214     raise ValueError("negative maxlength")
# --> 215 buf = self._recv_bytes(maxlength)
#     216 if buf is None:
#     217     self._bad_message_length()
#
# File ~/.pyenv/versions/3.11.4/lib/python3.11/multiprocessing/connection.py:413, in Connection._recv_bytes(self, maxsize)
#     412 def _recv_bytes(self, maxsize=None):
# --> 413     buf = self._recv(4)
#     414     size, = struct.unpack("!i", buf.getvalue())
#     415     if size == -1:
#
# File ~/.pyenv/versions/3.11.4/lib/python3.11/multiprocessing/connection.py:378, in Connection._recv(self, size, read)
#     376 remaining = size
#     377 while remaining > 0:
# --> 378     chunk = read(handle, remaining)
#     379     n = len(chunk)
#     380     if n == 0:
#
# KeyboardInterrupt:
